# %% [markdown]
# # Revised Version
#
# ### Jieyi Deng

# %% [markdown]
# ## Introduction
#
# The first part of the document is redesign and the second part is for deceptive version. In the first version of redesign, I did not write the reasoning clearly and my writing structure was hard to follow. Therefore, for the revised redesigned part, I rewrite everything to illustrate the development process, revision and the reasonings, following the GQM approach.
#
# Tableau Public Access: https://public.tableau.com/profile/jieyi.deng3205#!/

# %% [markdown]
# ## Redesign
# ## Finding 1: Higher gun ownership does not contribute to more gun homicides

# %% [markdown]
# ### Comparison
# The original Graph 6 is trying to verify that the higher the gun ownership rate, the higher number of gun homicides in a developed country. After redesigning and revising the graph, I found that it is hard to tell whether higher gun ownership result in more gun homicides in developed, developing or all countries, and developing countries in Central and South America have more gun deaths due to high frequency of violent crime. The comparison of the three graphs are shown below.

# %%
from IPython.display import Image
Image(filename='Graph_6.png', width=700)

# %%
Image(filename='redesign_1.png', width=900)

# %%
Image(filename='revised_1.png', width=900)

# %% [markdown]
# ### Development and Revision Process
# The original Graph 6 looks convincing at first glance: the points representing the countries are very tightly clustered around the best fit line and it seems that there is a high correlation between _Gun Related Death_ and _Gun Ownership_.
#
# However, after carefully looking at the graph, I found that the countries presented by the graph not only include developed countries, but some developing countries as well. Another problem is that the origin of the graph is not on the left bottom and the y-axis is shifted, making it harder to see whether the gun ownership rate actually has correlation with gun homicides or not. Thus, my goal is to use the same dataset to redraw this graph to corretly present the relationship between _Gun Related Death_ and _Gun Ownership_ without manipulating the origin and the y-axis.
#
# To do so, I decided to redesign the graph to include three dimensions: developed countries, developing countries and all the countries. The first step is to have a clear classification of the developed and developing countries. So I manually created a list of developed countries and developing countries based on the Country Classification Report by the UN (see below source 2).
#
# Then, I used a scatter plot and put all the countries available into the graph to get a whole picture: the dots seem to be quite random and most countries have a low rate of homicide by firearm per 100,000 population.  Next, I created a filter to seperate developed and developing countries to see if there is any differences between them. Finally, since the US looks like an outlier in the graph, I made another filter for including the US or not.
#
# To revise the graph, the multicolor representation of countries is replaced by monochrome. Unlike the first version, the revised redesign product uses yellow, blue and red to represent developing countries, developed countries and the US respectively. This enables readers to quickly clarify the different groups/categories by means of the color differences. The grid of the background is also removed to make the graph look cleaner. To see more data points clearly, the ranges of both x and y-axis are set to include negative numbers.

# %% [markdown]
# ### Reasoning
# After redesigning the graph, it is hard to tell that higher gun ownership contribute to more gun homicides in developed, developing or all countries.
#
# 1. Using the filter to get the developed countries including the US and the best fit linear trend line in Tableau,, it could be easily seen that the US is an outlier with the highest gun ownership and gun homicide death far away from other dots as well as the trend line. The R-squared of the linear trend line is only 0.51, indicating that the model explains only half of the variability of all the developed countries. There is no clear evidence that higher gun ownership will lead to more gun homicide deaths in developed countries.
#
# 2. If we look at the graph of developed countries without the US, the R-square of the linear trend line becomes even worse, with the model explains as little as 9% of the variability of all the developed countries. There is no clear evidence showing that more gun homicide deaths are resulting from higher gun ownership in developed countries excluding the US.
#
# 3. For the graph of all countries without the US, the R-squared is as little as 1.3% and it becomes even worse including the US (1%).
#
# 4. After revision, the color differences between developed and developing countries reveals that in general, developing countries have higher rate of homicide by firmarm the developed countries regardless of the gun ownership rate. Most of the developing countries with high gun homicide rate are central and south American countries due to frequent occurencies of violent crime (see below source 3).
#
# Therefore, it is hard to state that there is a correlation between _Gun Related Death_ and _Gun Ownership_. There is no specific evidence showing that more guns will give rise to more gun homicide deaths. In general, developing countries in Central and South America have much higher gun homicide rate no matter having high gun ownership rate or not.

# %% [markdown]
# ### Data Wrangling and Data Source:
#
# The data is obtained from the below two sources. The first one lists the gun homicides and gun ownership rate of 178 countries around the world, while the second one shows the classification of developed and developing countries.
#
# The first dataset is very clean except for various NAs that could be automatically excluded in Tableau. I entered the second dataset manully to get the list of countries classification.
#
# 1. The Guardian: Gun homicides and gun ownership listed by country
# <br>Retrieved from: https://www.theguardian.com/news/datablog/2012/jul/22/gun-homicides-ownership-world-list#data
#
# 2. United Nations: Country Classification Report
# <br>Retrieved from: http://www.un.org/en/development/desa/policy/wesp/wesp_current/2014wesp_country_classification.pdf
#
# 3. Amanda Erickson: Latin America is the world’s most violent region. A new report investigates why.
# <br> Retrieved from: https://www.washingtonpost.com/news/worldviews/wp/2018/04/25/latin-america-is-the-worlds-most-violent-region-a-new-report-investigates-why/?utm_term=.051a6260bed1

# %% [markdown]
# ## Finding 2: Stricker gun law could not reduce gun-related deaths

# %% [markdown]
# ### Comparison
# The original graph 8 of Vox uses a map to verify the statement that States with tighter gun control laws have fewer gun-related deaths in the US, while the redesigned version does not show clear relationship between these two. After revision, the final graph clearly reveals that stricter law alone could not reduce gun-related deaths. Other factors such as popoulation, economic status and crime rate of each state may influence the gun deaths as well.

# %%
Image(filename='Graph_8.jpg', width=700)

# %%
Image(filename='redesign_2.png', width=700)

# %%
Image(filename='redesign_3.png', width=600)

# %%
Image(filename='revised_2.png', width=900)

# %% [markdown]
# ### Development and Revision Process
#
# When I look at the original graph 8, I found it is difficult to read and whether there is any relationship between gun control laws and gun-related deaths is not clear. Despite having at least 1 firearm law to pretect children, states like Nevada still has really high number of gun deaths. In contrast, states without such a law, such as Washington and Oregon have relatively low gun deaths. It seems that the person created this graph in an attempt to cater the popular view that stricker laws can reduce gun violence. Thus, I redesign the graph 8, trying to figure out whether stringency of gun-control law have influence on gun-related deaths.
#
# It took me quite a while to get an indicator of the law stringency for each state and I finally decided to use the Brady-State-Scorecard as shown below because it's the most reliable one I could obtain. I first drew a scatter plot to see the overall trend of gun law stringency and gun deaths.
#
# Then, I divided the law score into five different levels and tried to see if lenient law will lead to higher gun deaths. To get these grades of law, I used "qcut" in Pandas package for five bins so that they will be chosen with the same number of records in each bin, and meanwhile the range of law score within each bin would not be too diverse. After cleaning the data, I graphed the average gun death per state for each law grade.
#
# Finally, I made improvement to the second graph so that I can see the figures of each state within these different five law grades. I also added a trend aveerage line for each bin of law grade so as to make comparison between different bins.
#
# The graph is available on Tableau Public:
# <br>

# %% [markdown]
# ### Reasoning
#
# 1. The first version of redesign shows a general idea about gun law and gun deaths. The model can only explain around 14% of the variability of all the states. It is hard to state that stricker gun control law could reduce gun-related deaths.
# 2. After categorizing the states by the degree of law stringency (using qcut to have five bins of grade with even frenquency), we could see that in general, states with stricker gun-control law seem to have a lower number of gun-related deaths. However, if we look at the average number of deaths for each state by law score grade, we can see the trend within each grade seems to be identical. Even though the average number of gun deaths shows an increase trend when the law becomes lenient, each law grade has states with low and high number of gun deaths.
# 3. States with less gun deaths such as New York, New Jersey, Massachusetts, Hawaii and California are economically advantaged (California has higher gun deaths rate compared with other four might because of its huge population and diversity), while states with more gun deaths such as Louisiana, Alabama and Missouri are generally considered to have higher crime rate. Therefore, besides the law, other factors may have huge influence on gun deaths as well.
#
# Thus, gun law stringency does not seem to have a huge impact on reducing gun-related deaths.

# %% [markdown]
# ### Data Wrangling and Data Source:
#
# The following two datasets are used for this redesign and the cleaning process is shown below.
#
# 1. Number of Deaths Due to Injury by Firearms per 100,000 Population from 2013 to 2016
# <br>Retrieved from: https://www.kff.org/other/state-indicator/firearms-death-rate-per-100000/?currentTimeframe=0&sortModel=%7B%22colId%22:%22Location%22,%22sort%22:%22asc%22%7D
#
# 2. Brady-State-Scorecard
# <br>Retrieved from: http://www.crimadvisor.com/?page=scorecard
#
# To get five different grades of law, the following data cleaning process is adopted:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# %pylab inline

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
# Clean the law-score dataset
law_score = pd.read_csv('Law-Score.csv')

# Normalize the total state points to a range of 0 to 1
law_score['TOTAL STATE POINTS']=(law_score['TOTAL STATE POINTS'] - law_score['TOTAL STATE POINTS'].min()
                              ) / (law_score['TOTAL STATE POINTS'].max() - law_score['TOTAL STATE POINTS'].min())

# Divide the states into five parts with even number of records in each bin
law_score['Gun Law Grade Even']=pd.qcut(law_score['TOTAL STATE POINTS'], 5, labels=["E", "D", "C", "B", "A"])

# %% [markdown]
# ## Finding 3: Polices are not more likely to be killed in homicides in states with more guns

# %% [markdown]
# ### Comparison
# Graph 14 states that police are more likely to be killed in homicides in states with more guns. After redesigning and revising the graphs, I found that polices are not more likely to be killed in homicides because of the high gun ownership of a state.

# %%
Image(filename='Graph_14.png', width=600)

# %%
Image(filename='redesign_4.png', width=600)

# %%
Image(filename='revised_3.png', width=900)

# %% [markdown]
# ### Development  and Revision Process
#
# The original graph on Vox only contains "Homicide rate per 10,000 law enforcement officers" for "high-gun states" and "low-gun states" without clear definition on the terms. This made me confused as I had no idea about which states are classified as high-gun and low-gun states and started to question the statement. Thus, I decided to redesign this graph so as to have a clear idea about the gun ownership rate in each state, as well as whether the statement of the graph is true.
#
# First, it took me a while to get the data for gun ownership in each state. There is no specific statistics about it and the only dataset I can obtain is the National Firearms Act Registered Weapons by State by April 2017. Thus, this is used for approximation of gun ownership for each state. Then, the gun ownership rate is divided into three categories with the same number of states in each categories as I think it is more reasonable to have three levels of gun ownership including high, medium and low instead of only high and low.
#
# Then I created a graph for average police killed/injured per year per state and it shows that states having highest rate of gun ownership are also states that have the most police killed or injured. There are not too much differences in number between the medium and low ownership rate.
#
# This does not prove my argument. So I designed another graph to see the figures of each state within these different three ownership grades. It seems that the patterns for each level of gun ownership are quite similar. This is especially true if we remove Nevada (since it could be regarded as an outlier owing to the Las Vegas mass shooting in 2017). Doing so will make the trends in each category looks identical and thus could justify the statement that polices are not more likely to be killed in homicides in states with more guns.
#
# By looking at the graph, it also shows that the figures of states like California, Florida, Texas and Georgia are more prominent compared with others. This will be further explained in the reasoning part.

# %% [markdown]
# ### Reasoning
#
# 1. For each level (low, medium and high) of gun ownership, the patterns are quite similar as each level has states with large number and small number of police injured or killed. After removing the outliner of Nevada that has a huge number of police injured or killed owing to the Las Vegas mass shooting in 2017, the patterns for these three levels are nearly identical. Thus, there is no clear evidence to support the statement of the original version on Vox that polices are more likely to be killed in homicides in states with more guns.
# 2. The figures of states like California, Florida, Texas and Georgia are more prominent compared with others. This may be result from the fact that these states have more police and law enforcement personnel than the others (see below source 4), which lead to a higher probability of police being killed or injured. It is not because of whether these states have more guns or not as they fall into all three levels of gun ownership.
# 3. Three different colors are used to present three levels of gun ownership, and average trend lines are also shown to see if there is any difference in general among all three levels. Grid lines on the background are also removed as there is need of grid lines given the figures for each bar are presented.

# %% [markdown]
# ### Data Wrangling and Data Source:
#
# To redesign this graph, the following sources are obtained. For the first dataset, since I cannot find data estimating the population by the end of 2017, I use the numbers up to July 2017 as an approximation. This population dataset is used to get the gun ownership per capita in each state. The second dataset only covers data by April 2017 and only contains information of registered guns. Since I cannot find any other dataset related to gun ownership by state, I use this dataset as an approximation. This may cause inaccuracy due to the data incompleteness.
#
# 1. Annual Estimates of the Resident Population for the United States by States
# <br>Retrieved from: https://www.census.gov/data/tables/2017/demo/popest/state-total.html)
# 2. National Firearms Act Registered Weapons by State (April 2017)
# <br>Retrieved from: https://www.atf.gov/resource-center/docs/undefined/firearms-commerce-united-states-annual-statistical-update-2017/download
# 3. Number of officer Shot or Killed in Gun Violence Incidents from 2014 to 2017
# <br>Retrieved from: http://www.gunviolencearchive.org/past-tolls
# 4. U.S. States With The Most Police And Law Enforcement Personnel
# <br>https://www.worldatlas.com/articles/u-s-states-with-the-most-police-and-law-enforcement-personnel.html
#
# The data cleaning process is shown as follows:

# %%
# Clean the population and gun ownership dataset
population = pd.read_csv('Population.csv')
gun_ownership = pd.read_csv('GunOwnership.csv')

gun_ownership = population.merge(gun_ownership, left_on='State', right_on='Location', how='inner')

# Drop useless column and create new columns to represent gun per 1000 people and gun ownership grade
gun_ownership.drop('Location', axis=1, inplace=True)

gun_ownership['Gun Ownership by April 2017'] = gun_ownership['Gun Ownership by April 2017'].astype(int)

gun_ownership['Gun per 1000 people'] = gun_ownership['Gun Ownership by April 2017'] / gun_ownership[
    'Population Estimate by July 1 in 2017'] * 1000

gun_ownership['Gun Ownership Grade']=pd.qcut(gun_ownership['Gun per 1000 people'], 3, labels=["C", "B", "A"])

# %% [markdown]
# ## Deceptive
# ## Finding 1: There are more and more gun deaths in the U.S. since 2000

# %% [markdown]
# ### Comparison
# The original graph 9 illustrates that gun homicides have declined over the past years in the U.S. After making deceptive version and revision, there is an increasing trend of gun deaths in the U.S. from the start of 21st century.

# %%
from IPython.display import Image
Image(filename='Graph_9.png', width=600)

# %%
Image(filename='redesign_5.png', width=650)

# %%
Image(filename='revised_4.png', width=650)

# %% [markdown]
# ### Development and Revision Process
# When I looked at the Graph 8, I noticed that even though the overall gun homicides rate has declined over the past few decades, there is a slight trend of increase from year 2000. Thus, I cherry picked this time frame to make the first deceptive graph and used it as a favorable evidence to support my first finding.
#
# I started with a graph describing the _rate of firearm homicide deaths_ from 2000 to 2010 to see the trend. Then, I checked the original data source and gained data from year 2011 to 2015 to create a new chart.
#
# To make a better deceptive version and support an opposite conclusion from the Vox version, I graphed _the count of firearm homicide deaths_ within the same period of 2000 to 2008 with a clearer increase in absolute number compared to ratio. Then, I also tried the _total firearm deaths_ with gun deaths of all intents and added the year from 2009 to 2015 for revision and I obtained a version with nearly constant increase in number from 2000 to 2015. Here, I used the same dataset but from a different matrix. Single color is used as there is only one category and background grids are removed to make the graph clearer.
#
# In this process, I followed the audience model. I specified my audience to be those who want to get tighter gun control. Thus, creating a graph that shows a growing trend in gun deaths can cater these audience, making them think that it is necessary to control guns. But for those unintended audience, they may question about the absolute numbers and would argue that there is no huge increase in the rate.
#
# Finally, I manipulated the axes to make the graph more misleading. Specifically, the y-axis is truncated and the x-axis is shorten to exaggerate the pattern of change. I also put my argument on the graph to make it more clear.
#
# Please visit the Tableau Public for all these versions: <br>https://public.tableau.com/profile/jieyi.deng3205#!/vizhome/Graph9deceptive/FirearmDeaths2000-2015

# %% [markdown]
# ### Reasoning
# Compared with the original product, this is a deceptive version based on the following reasons:
# 1. The time frame is cherry picked to show only the trend from 2000 to 2015, where an constant increase happened, rather the whole picture from 1981.
# 2. Instead of the Firearm Homicide Deaths or the Rate of Firearm Homicide Deaths, the Firearm Deaths data with gun deaths resulted from all intents is used to mislead the readers as most people would not realize the huge composition of gun suicides if it is not pointed out. Also, the absolute count number shows an obvious increasing trend while the actual rate of firearm homicide deaths decreases from 1993 and maintain stable starting from 2000. This further misleads those who would like to control guns.
# 3. The y-axis is manipulated with a fixed range starting from 25,500 and ending at 38,500 to make the increasing trend look sharper.

# %% [markdown]
# ### Data Wrangling and Data Source:
# As briefly described in the development process, I first designed a deceptive graph showing an growing from 2000 to 2006 and then a decline till 2010 of the _Rate of Firearm Homicide Deaths_. Then, I obtained data from year 2011 to 2015 and a graph illustrating that the rate has a fluctuation from 2011 to 2014 and increases again from 2014 to 2015.
#
# Since my goal is to make a deceptive version and support my finding, I graphed again but with the count of firearm homicide deaths from 2000 to 2015 since there is a clearer increase in absolute number compared to ratio. Finally, I picked the total firearm deaths including not only homicide but also all the other intents and I gained a version with nearly constant increase in number from 2000 to 2015, which could be a quite deceptive graph to readers.
#
# Data from year 1999 to 2010 are obtained through the first source, a report from the Pew Research Center. Since the report use data from Centers for Disease Control, I go to the original source to get more information about the dataset. However, there is no way to download the dataset from 1999 to 2015. Thus, I input the _Year_, _the Count of Firearm Deaths_, _the Count of Firearm Homicide Deaths_ and _the Rate of Firearm Homicide Deaths_ into a csv file manually. The dataset is pretty clean so I do not need to spend much time on it.
#
# 1. Pew Research Center: Gun Homicide Rate Down 49% Since 1993 Peak; Public Unaware (Appendix 1)
# <br>Retrieved from: http://www.pewsocialtrends.org/2013/05/07/appendix-1-additional-tables-on-firearm-deaths/
#
# 2. Centers for Disease Control and Prevention: Fatal Injury Reports, National and Regional, 1999 - 2015
# <br>Retrieved from: https://webappa.cdc.gov/sasweb/ncipc/mortrate10_us.html

# %% [markdown]
# ## Finding 2: America does not seem to have much more firearm homicides than other countries.

# %% [markdown]
# ### Comparison
# The original graph 1 of Vox demonstrates that America has higher firearm homicides than other developed countries.

# %%
Image(filename='Graph_1.jpg', width=500)

# %% [markdown]
# The deceptive version makes America seem not to have much more firearm homicides than other developed countries.

# %%
Image(filename='Decpt_Graph_1.png', width=800)

# %%
Image(filename='revised_5.png', width=800)

# %% [markdown]
# ### Development and Revision Process
# To get a deceptive graph 1 and use the new graph to prove the second finding, I intentionally picked 12 developed countries that have higher firearm homicide rate among all of the 36 developed countries categorized based on the Country Classification Report by the UN (see below source 2), so that the gap between the U.S. and other developed countries could be as smaller as possible.
#
# Then, the x-axis is manipulated through the logarithmic scaling to make rate of the U.S. and the other developed countries look much closer. The range of the x-axis is deliberately set fixed from 0.001 to 3.5 and the largest tick mark is set as 1 to let the different countries look of similar values. The bar of each country is deliberately widened so that the differences in values look even smaller.
#
# To make a revision, I followed the argumentation model and tried to creat a graph claiming that the US does not have a high gun homicide rate compared with other countries. To further support my argument, I deleted 6 developed countries whith low gun homicide rate and instead, cherry picking 8 developing countries with high gun homicide rate. This makes the graph more deceptive to those who do not want more gun controls as the US does not seem to have huge gun death problems compared with other countries. The argument is added to the graph to make it more clear.
#
# Two colors are used to make better comparison for the US and other countries, and background grids are removed to make the graph clearer. The tick interval is set to
#
# The graph is available on Tableau Public: <br>https://public.tableau.com/profile/jieyi.deng3205#!/vizhome/Graph1Deceptive/HomicidesbyFirearm

# %% [markdown]
# ### Reasoning
#
# 1. The added developing countries are intentionally chosed to show that many other countries have high or similar gun homicide death rate to that of the US. This further verify my statement of "America does not seem to have much more firearm homicides than other countries" and make those who do not want gun control to confirm their believes.
# 2. If the readers are not familiar with the concept of log scales, the graph using a log scale can be rather misleading. Such a change in scale leads to a representation that allows data values to be appered in similar size while in reality, they have widely differing magnitudes (see below source 3).

# %% [markdown]
# ### Data Wrangling and Data Source:
#
# As shown above, the first step is to cherry pick the data and include countries with higher rate of firearm homicde rate to narrow down the huge gap between the U.S. and other developed countries.
#
# To minimize the differences visually, the log scaling is adopted to give ones the impression that there is little difference between the rate of U.S. and other developed countries selected. Specifically, the U.S. has a figure of 29.7 homicides by guns per 1 million people and the second largest one is Switzerland with a number of 7.7. The difference between these two countries is huge in the original graph, not to mention comparing the U.S. to other countries with even smaller number. On a log scale in the deceptive version, the length of these two bars are much more similar.
#
# The dataset is easy to get from the first source listed below and it is clean to use as well.
#
# 1. The Guardian: Gun homicides and gun ownership listed by country
# <br>Retrieved from: https://www.theguardian.com/news/datablog/2012/jul/22/gun-homicides-ownership-world-list#data
#
# 2. United Nations: Country Classification Report
# <br>Retrieved from: http://www.un.org/en/development/desa/policy/wesp/wesp_current/2014wesp_country_classification.pdf
#
# 3. Harvey, J. Motulsky (June 2009). "The Use and Abuse of Logarithmic Axes"
# <br>Retrived from: https://web.archive.org/web/20101123050530/http://graphpad.com/faq/file/1487logaxes.pdf

# %% [markdown]
# ## Finding 3: High-profile shootings lead to more support for gun control

# %% [markdown]
# ### Comparison
# The original graph demonstrates that High-profile shootings do not lead to more support for gun control.

# %%
Image(filename='Graph_16.png', width=500)

# %% [markdown]
# The deceptive version appears to present the opposite: high-profile shootings do lead to more support for gun control.

# %%
Image(filename='Decpt_Graph_16.png', width=400)

# %%
Image(filename='revised_6.png', width=900)

# %% [markdown]
# ### Development and Revision Process
#
# To begin with, I created a graph with all the three locations of the original but it did not have many differences compared with the original one. Since my target is to present a larger change of the views on controlling guns and protecting rights before and after shootings, I decided to truncated the y-axis first since the values for the two views on different states before and after shootings are within a narrow range. After doing so, the small differences are exaggerated to make a deceptive impression.
#
# After looking at the results of different states, I found the data for Tucson AZ present a result that contradict to my statement: the percentage of supporting gun control drops after the shooting, while the one for protecting rights increases. Thus, I deliberately omitted the data for Tucson AZ to make my deceptive version coherent. The size of the bar is adjusted to be thinner, resulting in a visually huger increase.
#
# To get a better version, I first put the argument as the title of the graph. I reverse the columns and rows in Tableau and then reverse the direction of _% of Protect Right to Own Guns_, making the bars of the two columns starting from the middle so that readers can clearly make comparison between these two categories. Different colors are used to clarify the two categories and grids are moved as well because I don't want the readers to focus on the actual amount of increase/decrease.
#
# The deceptive version is available on Tableau Public:
# <br>https://public.tableau.com/profile/jieyi.deng3205#!/vizhome/Graph16deceptive/GunControlViewShiftafterShooting

# %% [markdown]
# ### Reasoning
# Compared with the original product, this is a deceptive version based on the following reasons:
# 1. The y-axis is truncated with a fixed range from 44% to 61% and 31% to 50% for _Control Gun Ownership_ and _Protect Rights to Own Guns_ respectively to create an exaggeration of the trends. It gives a misleading first impression that the percentage of _Control Gun Ownership_ goes up substantially while the one for _Protect Rights to Own Guns_ goes down a lot, and that public is in favor of protecting rights to own guns in Aurora CO while people prefer controlling gun ownership in Virginia Tech.
# 2. Omitting the opposite idea presented using Tucson AZ data so that the deceptive statement would be more convincing.
# 3. The axis are reversed and color are changed to make the differences of the two categories more prominent. This version gives readers a sence that after gun shooting, gun control are more favored by people while percentage of protecting right to own guns decreases a lot in both of the two states. Also, it seems to present a idea that compared with Aurora, there are more people supporting gun control in Virginia Tech.

# %% [markdown]
# ### Data Wrangling and Data Source:
#
# To get a coherent results and a deveptive version, the data of Tucson AZ is ommited intentionally.
#
# The data of this graph is collected by Pew Research Center through survey. However, there is no dataset to download from the website. Thus, I input the _Time_, _the Percentage of Gun Control Ownership_, _the Percentage of Right to Own Guns_ and _Location_ into a csv file manually. The dataset is pretty clean so I do not need to spend much time on it.
#
# 1. Pew Research Center: Views on Gun Laws Unchanged After Aurora Shooting
# <br>Retrieved from: http://www.people-press.org/2012/07/30/views-on-gun-laws-unchanged-after-aurora-shooting/

# %% [markdown]
# #### All the original graphs are downloaded from:
# America’s unique gun violence problem, explained in 17 maps and charts：
# <br>https://www.vox.com/policy-and-politics/2017/10/2/16399418/us-gun-violence-statistics-maps-charts
